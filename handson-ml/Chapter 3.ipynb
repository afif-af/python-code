# %% [markdown]
# <a href="https://www.kaggle.com/code/afifaf20/03-classification?scriptVersionId=199206948" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>
