# %% [markdown]
# <a href="https://www.kaggle.com/code/afifaf20/numpyarrayobject?scriptVersionId=198783062" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np

# %%
data =np.array([[1.5,-0.1,3],[0,-3,6.5]])

# %%
data
# Out:
# array([[ 1.5, -0.1,  3. ],
#        [ 0. , -3. ,  6.5]])
